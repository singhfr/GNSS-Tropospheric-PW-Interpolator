# %% [markdown]
# # GNSS Tropospheric PW Interpolation - ML Training & Evaluation Demo
#
# This notebook demonstrates the machine learning pipeline for GNSS precipitable water interpolation.
#
# ## Overview
# - Load and explore GNSS ZWD data
# - Train multiple interpolation models (GPR, IDW, baselines)
# - Evaluate model performance
# - Visualize interpolation results
# - Demonstrate forecasting capabilities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set style
plt.style.use('default')
sns.set_palette("husl")
